# %% [markdown]
# <a href="https://colab.research.google.com/github/SPraveen69/Data_Model/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Import the Lib**

# %%
import pandas as pd
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ### **Uploading the Dataset**

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Set the path to the CSV file in your Google Drive
file_path = '/content/drive/MyDrive/BDX Dataset/medical center details.xlsx'

# Load the CSV file into a DataFrame
data = pd.read_excel(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Data Preprocessing**

# %%
data.shape
# Out:
# (7285, 49)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7285 entries, 0 to 7284
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         7285 non-null   object
#  1   EPF No                       6816 non-null   object
#  2   Time                         0 non-null      float64
#  3   Employee No                  6270 non-null   float64
#  4   Name With Initials           7273 non-null   object
#  5   Calling Name                 7274 non-null   object
#  6   Department                   7114 non-null   object
#  7   Roster                       6267 non-null   object
#  8   Shift                        6361 non-null   object
#  9   Symptoms                     6514 non-null   object
#  10  Reporting Type               7191 non-null   object
#  11  Treatments                   337 non-null    object
#  12  Paracetamol                  3171 non-null   float64
#  13  Vitamin B                    0 non-null      float64
#  14  Vitamin C                    1672 non-null   float64
#  15   Digene Tablet               850 non-null    float64
#  16  Crape Bandage                0 non-null      float64
#  17  Samahan                      106 non-null    float64
#  18  Jeewani                      54 non-null     float64
#  19  Bed Rest In time             56 non-null     datetime64[ns]
#  20  Bed Rest Out time            55 non-null     datetime64[ns]
#  21  Entered By                   6346 non-null   object
#  22  Hospital Visit               7 non-null      object
#  23  Hospital Name                183 non-null    object
#  24  Date of Visit                2 non-null      object
#  25  Visited Nurse                207 non-null    object
#  26  Remark                       903 non-null    object
#  27  Reason                       0 non-null      float64
#  28  Brandix Employee/Contractor  0 non-null      float64
#  29  Created                      7285 non-null   datetime64[ns]
#  30  Created By                   7285 non-null   object
#  31  Modified By                  7285 non-null   object
#  32  Modified                     7285 non-null   datetime64[ns]
#  33  Hospital Refer/ Sent Home    0 non-null      float64
#  34  BP                           20 non-null     object
#  35  Pulse                        0 non-null      float64
#  36  Temperature                  0 non-null      float64
#  37  SpO2                         0 non-null      float64
#  38  Patient Type                 5674 non-null   object
#  39  Eno                          0 non-null      float64
#  40  Complain                     939 non-null    object
#  41  Communicable Diseases        162 non-null    object
#  42  Hospital Stay/ Home Stay     273 non-null    object
#  43  Return to work Date          1 non-null      datetime64[ns]
#  44  Plant                        0 non-null      float64
#  45  Contact Number               0 non-null      float64
#  46  ID                           7285 non-null   int64
#  47  Item Type                    7285 non-null   object
#  48  Path                         7285 non-null   object
# dtypes: datetime64[ns](5), float64(18), int64(1), object(25)
# memory usage: 2.7+ MB

# %%
# replace unwanted values with nan
# data = data.replace('#DIV/0!', np.nan)

# returns the total number of missing values for each column
data.isnull().sum()
# Out:
# Date                              0
# EPF No                          469
# Time                           7285
# Employee No                    1015
# Name With Initials               12
# Calling Name                     11
# Department                      171
# Roster                         1018
# Shift                           924
# Symptoms                        771
# Reporting Type                   94
# Treatments                     6948
# Paracetamol                    4114
# Vitamin B                      7285
# Vitamin C                      5613
#  Digene Tablet                 6435
# Crape Bandage                  7285
# Samahan                        7179
# Jeewani                        7231
# Bed Rest In time               7229
# Bed Rest Out time              7230
# Entered By                      939
# Hospital Visit                 7278
# Hospital Name                  7102
# Date of Visit                  7283
# Visited Nurse                  7078
# Remark                         6382
# Reason                         7285
# Brandix Employee/Contractor    7285
# Created                           0
# Created By                        0
# Modified By                       0
# Modified                          0
# Hospital Refer/ Sent Home      7285
# BP                             7265
# Pulse                          7285
# Temperature                    7285
# SpO2                           7285
# Patient Type                   1611
# Eno                            7285
# Complain                       6346
# Communicable Diseases          7123
# Hospital Stay/ Home Stay       7012
# Return to work Date            7284
# Plant                          7285
# Contact Number                 7285
# ID                                0
# Item Type                         0
# Path                              0
# dtype: int64

# %%
data
# Out:
#                   Date EPF No  Time  Employee No   Name With Initials  \
# 0     26/06/2024 11:18  26813   NaN    1008008.0      Y.M.W.G.Mallika
# 1     26/06/2024 11:18    NaN   NaN          NaN              Sujeewa
# 2     26/06/2024 14:08  28616   NaN    1045160.0       W.D.ASHOKAMALA
# 3     26/06/2024 14:09  29057   NaN    1084133.0       H.M.C.D.Herath
# 4     26/06/2024 14:09  23185   NaN      98753.0          R.Jelastina
# ...                ...    ...   ...          ...                  ...
# 7280  26/06/2024 09:41  28062   NaN    1031581.0   J.A.M.S.Jayasingha
# 7281  26/06/2024 09:42  29529   NaN          NaN             Susanthi
# 7282  26/06/2024 09:45  29569   NaN          NaN              Milinda
# 7283  26/06/2024 09:47    NaN   NaN          NaN             Kugandya
# 7284  26/06/2024 11:16  28866   NaN    1054059.0  S.P.A.K.AMARASINGHE
#
#      Calling Name      Department             Roster Shift        Symptoms  \
# 0         Mallika   Manufacturing   Team G - Shift B     B       body Pain
# 1         Sujeewa     Third party                NaN   NaN       Back Pain
# 2         Dilhani   Manufacturing  Team 11 - Shift A     A        Eye Pain
# 3         Chamila   Manufacturing  Team 23 - Shift A     A            Cold
# 4       Jelastina   Manufacturing  Team 09 - Shift A     A            Cold
# ...           ...             ...                ...   ...             ...
# 7280   Maduwanthi   Manufacturing  Team 12 - Shift B     B      Tooth Pain
# 7281     Susanthi   Manufacturing                NaN   NaN     Cold ,Fever
# 7282      Milinda         Cutting                NaN   NaN           Cough
# 7283     Kugandya   Manufacturing                NaN   NaN  Allergies,Rash
# 7284       Anusha  Medical Centre   Team G - Shift G     G        Headache
#
#       ... Eno Complain  Communicable Diseases  Hospital Stay/ Home Stay  \
# 0     ... NaN      NaN                    NaN                       NaN
# 1     ... NaN      NaN                    NaN                       NaN
# 2     ... NaN      NaN                    NaN                       NaN
# 3     ... NaN      NaN                    NaN                       NaN
# 4     ... NaN      NaN                    NaN                       NaN
# ...   ...  ..      ...                    ...                       ...
# 7280  ... NaN      NaN                    NaN                       NaN
# 7281  ... NaN      NaN                    NaN                       NaN
# 7282  ... NaN      NaN                    NaN                       NaN
# 7283  ... NaN      NaN                    NaN                       NaN
# 7284  ... NaN      NaN                    NaN                       NaN
#
#       Return to work Date  Plant  Contact Number     ID  Item Type  \
# 0                     NaT    NaN             NaN  10000       Item
# 1                     NaT    NaN             NaN  10001       Item
# 2                     NaT    NaN             NaN  10002       Item
# 3                     NaT    NaN             NaN  10003       Item
# 4                     NaT    NaN             NaN  10004       Item
# ...                   ...    ...             ...    ...        ...
# 7280                  NaT    NaN             NaN   9995       Item
# 7281                  NaT    NaN             NaN   9996       Item
# 7282                  NaT    NaN             NaN   9997       Item
# 7283                  NaT    NaN             NaN   9998       Item
# 7284                  NaT    NaN             NaN   9999       Item
#
#                                                    Path
# 0     sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 1     sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 2     sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 3     sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 4     sites/BEKTMedicalCenter/Lists/Patient_Details_...
# ...                                                 ...
# 7280  sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 7281  sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 7282  sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 7283  sites/BEKTMedicalCenter/Lists/Patient_Details_...
# 7284  sites/BEKTMedicalCenter/Lists/Patient_Details_...
#
# [7285 rows x 49 columns]

# %%
#retrieve all columns of data
data.columns
# Out:
# Index(['Date', 'EPF No', 'Time', 'Employee No', 'Name With Initials',
#        'Calling Name', 'Department', 'Roster', 'Shift', 'Symptoms',
#        'Reporting Type', 'Treatments', 'Paracetamol', 'Vitamin B', 'Vitamin C',
#        ' Digene Tablet', 'Crape Bandage', 'Samahan', 'Jeewani',
#        'Bed Rest In time', 'Bed Rest Out time', 'Entered By', 'Hospital Visit',
#        'Hospital Name', 'Date of Visit', 'Visited Nurse ', 'Remark', 'Reason',
#        'Brandix Employee/Contractor', 'Created', 'Created By', 'Modified By',
#        'Modified', 'Hospital Refer/ Sent Home', 'BP ', 'Pulse ', 'Temperature',
#        'SpO2', 'Patient Type', 'Eno', 'Complain', 'Communicable Diseases',
#        'Hospital Stay/ Home Stay', 'Return to work Date', 'Plant',
#        'Contact Number', 'ID', 'Item Type', 'Path'],
#       dtype='object')

# %%
# drop unwanted columns in data
columns = ['Date','EPF No','Department','Shift','Symptoms']
data = data[columns]

# %%
#remove all the null row values
data = data.dropna()
data
# Out:
#                   Date EPF No      Department Shift      Symptoms
# 0     26/06/2024 11:18  26813   Manufacturing     B     body Pain
# 2     26/06/2024 14:08  28616   Manufacturing     A      Eye Pain
# 3     26/06/2024 14:09  29057   Manufacturing     A          Cold
# 4     26/06/2024 14:09  23185   Manufacturing     A          Cold
# 5     26/06/2024 14:10  23887   Manufacturing     A          Cold
# ...                ...    ...             ...   ...           ...
# 7276  26/06/2024 09:26  21603       Technical     G  Loose Motion
# 7278  26/06/2024 09:33  21182   Manufacturing     B          Cold
# 7279  26/06/2024 09:40  12864   Manufacturing     B     Hand Pain
# 7280  26/06/2024 09:41  28062   Manufacturing     B    Tooth Pain
# 7284  26/06/2024 11:16  28866  Medical Centre     G      Headache
#
# [5541 rows x 5 columns]

# %%
# Count the occurrences of each department and synptoms
department_counts = data['Department'].value_counts()
symptoms_counts = data['Symptoms'].value_counts()

# Print the results
print("Department Counts:")
print(department_counts)

print("\nSymptoms Counts:")
print(symptoms_counts)
# Out:
# Department Counts:
# Department
# Manufacturing                   3385
# Finishing                        474
# Warehouse                        339
# Quality Assurance                323
# Cutting                          275
# Training School                  149
# RM Inspection                     78
# Machine Maintenance               77
# Technical                         73
# Medical Centre                    59
# Central Inspection Facility       50
# Pilot Zone                        43
# Facility Management               37
# Industrial Engineering            31
# Operations                        24
# General Administration            16
# Indirect                          13
# Finishing & Packing               12
# Planning                          11
# Occupational Health & Safety       9
# Works HR                           9
# Direct                             8
# Packing                            7
# HR                                 4
# Executive                          3
# HR & Administration                3
# Training school                    3
# Admin                              3
# ICT Operations                     2
# Medical Center                     2
# Engineering                        1
# Traning Line                       1
# Digital Operations                 1
# Training School                    1
# Headache                           1
# executive                          1
# Council                            1
# Jumper                             1
# Team -09                           1
# Line23                             1
# Manufaccharing                     1
# P.Manager                          1
# Security                           1
# security                           1
# G.T.                               1
# Manufaturing                       1
# Training Scool                     1
# Good Transport                     1
# Taraining School                   1
# Name: count, dtype: int64
#
# Symptoms Counts:
# Symptoms
# Cold             1249
# Headache         1055
# Gastric           393
# Gastritis         343
# URTI              217
#                  ...
# Allergic Rash       1
# BP                  1
# cold,headache       1
# Hedache,Cold        1
# Headache/Cold       1
# Name: count, Length: 402, dtype: int64

# %%
# Encode categorical variables
label_encoders = {}
for column in ['Department', 'Symptoms']:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])

# %%
import re
# Function to clean date strings
def clean_date(date_str):

    date_str = re.sub(r'\.', ':', date_str)
    date_str = re.sub(r'(\d{1,2})([ap]m)', r'\1 \2', date_str)  # Handle am/pm without space
    return date_str

# %%
# Apply the function to the Date column
data['Date'] = data['Date'].apply(clean_date)

# Convert the cleaned Date column to datetime
data['Date'] = pd.to_datetime(data['Date'], errors='coerce', infer_datetime_format=True)
data['year'] = data['Date'].dt.year
data['day_of_week'] = data['Date'].dt.dayofweek
data['month'] = data['Date'].dt.month
# Out:
# <ipython-input-510-267ae31076c8>:5: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data['Date'] = pd.to_datetime(data['Date'], errors='coerce', infer_datetime_format=True)
# <ipython-input-510-267ae31076c8>:5: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Date'] = pd.to_datetime(data['Date'], errors='coerce', infer_datetime_format=True)

# %%
data
# Out:
#                     Date EPF No  Department Shift  Symptoms    year  \
# 0    2024-06-26 11:18:00  26813          24     B       373  2024.0
# 2    2024-06-26 14:08:00  28616          24     A        92  2024.0
# 3    2024-06-26 14:09:00  29057          24     A        69  2024.0
# 4    2024-06-26 14:09:00  23185          24     A        69  2024.0
# 5    2024-06-26 14:10:00  23887          24     A        69  2024.0
# ...                  ...    ...         ...   ...       ...     ...
# 7276 2024-06-26 09:26:00  21603          39     G       207  2024.0
# 7278 2024-06-26 09:33:00  21182          24     B        69  2024.0
# 7279 2024-06-26 09:40:00  12864          24     B       148  2024.0
# 7280 2024-06-26 09:41:00  28062          24     B       323  2024.0
# 7284 2024-06-26 11:16:00  28866          27     G       155  2024.0
#
#       day_of_week  month
# 0             2.0    6.0
# 2             2.0    6.0
# 3             2.0    6.0
# 4             2.0    6.0
# 5             2.0    6.0
# ...           ...    ...
# 7276          2.0    6.0
# 7278          2.0    6.0
# 7279          2.0    6.0
# 7280          2.0    6.0
# 7284          2.0    6.0
#
# [5541 rows x 8 columns]

# %%
# Aggregate symptoms count by department and date
aggregated_data = data.groupby(['year', 'month', 'day_of_week', 'Department']).agg({
    'Symptoms': lambda x: x.mode()[0],  # Most common symptom for that day
}).reset_index()

# %%
# Create lag features for symptoms
aggregated_data['symptom_lag_1'] = aggregated_data.groupby('Department')['Symptoms'].shift(1)
aggregated_data['symptom_lag_2'] = aggregated_data.groupby('Department')['Symptoms'].shift(2)
aggregated_data.dropna(inplace=True)

# %%
aggregated_data
# Out:
#        year  month  day_of_week  Department  Symptoms  symptom_lag_1  \
# 13   2024.0    5.0          1.0          24        69           69.0
# 20   2024.0    5.0          2.0           1       125          155.0
# 22   2024.0    5.0          2.0           9        69          155.0
# 24   2024.0    5.0          2.0          24        69           69.0
# 29   2024.0    5.0          2.0          34       148           69.0
# ..      ...    ...          ...         ...       ...            ...
# 188  2024.0    7.0          5.0          24       155          155.0
# 189  2024.0    7.0          5.0          34        69           69.0
# 190  2024.0    7.0          5.0          35       155           69.0
# 191  2024.0    7.0          5.0          40       155          117.0
# 192  2024.0    7.0          5.0          45        69           69.0
#
#      symptom_lag_2
# 13            69.0
# 20           155.0
# 22           373.0
# 24            69.0
# 29            69.0
# ..             ...
# 188           69.0
# 189          125.0
# 190          125.0
# 191           69.0
# 192           69.0
#
# [145 rows x 7 columns]

# %% [markdown]
# ### Sepearting the features and target

# %%
# Define features and target variable
X = aggregated_data[['year', 'month', 'day_of_week', 'Department', 'symptom_lag_1', 'symptom_lag_2']]
y = aggregated_data['Symptoms']


# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=80)

# %% [markdown]
# ### Predicting symptoms using randon forest

# %%
# Initialize and train the model
model = RandomForestClassifier(n_estimators=1000, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4772727272727273
#               precision    recall  f1-score   support
#
#           43       0.00      0.00      0.00         0
#           69       0.53      0.79      0.63        24
#          125       0.00      0.00      0.00         5
#          148       0.00      0.00      0.00         1
#          155       0.33      0.22      0.27         9
#          264       0.00      0.00      0.00         1
#          266       0.00      0.00      0.00         1
#          307       0.00      0.00      0.00         1
#          323       0.00      0.00      0.00         2
#
#     accuracy                           0.48        44
#    macro avg       0.10      0.11      0.10        44
# weighted avg       0.36      0.48      0.40        44
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### User Input

# %%
from datetime import datetime, timedelta

department = 'Manufacturing'
input_date = datetime.strptime('2024-08-06', '%Y-%m-%d')

# Create a DataFrame with the same structure as the training data
input_data = pd.DataFrame({
    'year': [input_date.year],
    'month': [input_date.month],
    'day_of_week': [input_date.weekday()],
    'Department': [label_encoders['Department'].transform([department])[0]],
    'symptom_lag_1': [0],
    'symptom_lag_2': [0]
})

predicted_symptoms = model.predict(input_data)
print(f'Predicted symptoms for {department} on {input_date.date()}: {label_encoders["Symptoms"].inverse_transform(predicted_symptoms)[0]}')
# Out:
# Predicted symptoms for Manufacturing on 2024-08-06: Cold
